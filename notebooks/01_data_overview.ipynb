# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

print("Notebook: 01_data_overview")
print("Goal: Inspect raw datasets and understand structure before cleaning.")
# Out:
# Notebook: 01_data_overview
# Goal: Inspect raw datasets and understand structure before cleaning.

# %%
notes = {
    "season_tested": "2019-2020",
    "data_sources_planned": ["FBref", "Transfermarkt", "Capology"],
    "checks_to_run": [
        "column names",
        "missing values",
        "duplicates",
        "data types",
        "club name consistency",
        "season format consistency",
        "currency formats"
    ]
}
notes
# Out:
# {'season_tested': '2019-2020',
#  'data_sources_planned': ['FBref', 'Transfermarkt', 'Capology'],
#  'checks_to_run': ['column names',
#   'missing values',
#   'duplicates',
#   'data types',
#   'club name consistency',
#   'season format consistency',
#   'currency formats']}
